# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
# TODO: Make all necessary imports.
from __future__ import absolute_import, division, print_function, unicode_literals

import os
import json
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
print('Using:')
print('\t\u2022 TensorFlow version:', tf.__version__)
print('\t\u2022 tf.keras version:', tf.keras.__version__)
print('\t\u2022 Running on GPU' if tf.test.is_gpu_available() else '\t\u2022 GPU device not found. Running on CPU')
# Out:
# Using:
# 	• TensorFlow version: 2.1.0
# 	• tf.keras version: 2.2.4-tf
# 	• Running on GPU

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums=True --datasets=oxford_flowers102
# Out:
# I0508 00:27:30.458330 140300685535040 download_and_prepare.py:194] Running download_and_prepare for dataset(s):
# oxford_flowers102
# I0508 00:27:31.014713 140300685535040 dataset_info.py:427] Load pre-computed DatasetInfo (eg: splits, num examples,...) from GCS: oxford_flowers102/2.1.1
# I0508 00:27:32.358146 140300685535040 dataset_info.py:358] Load dataset info from /tmp/tmp4epxuex6tfds
# I0508 00:27:32.383171 140300685535040 download_and_prepare.py:133] download_and_prepare for dataset oxford_flowers102/2.1.1...
# I0508 00:27:32.383849 140300685535040 dataset_builder.py:333] Generating dataset oxford_flowers102 (/home/dimitriosrou/tensorflow_datasets/oxford_flowers102/2.1.1)
# Downloading and preparing dataset oxford_flowers102/2.1.1 (download: 328.90 MiB, generated: 331.34 MiB, total: 660.25 MiB) to /home/dimitriosrou/tensorflow_datasets/oxford_flowers102/2.1.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0508 00:27:32.864717 140300685535040 download_manager.py:301] Downloading https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz into /home/dimitriosrou/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_102flowersoWedSp98maBn1wypsDib6T-q2NVbO40fwvTflmPmQpY.tgz.tmp.5c8c958e3fc84cab9f2940606098aa43...
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0508 00:27:32.867250 140300685535040 download_manager.py:291] URL https://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat already downloaded: reusing /home/dimitriosrou/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_imagelabelSQPpQga6wjv3cqrfBkUZFt9WtY_Eg6YtsyqXuCZWZR0.mat.
# I0508 00:27:32.873366 140300685535040 download_manager.py:318] Skipping extraction for /home/dimitriosrou/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_imagelabelSQPpQga6wjv3cqrfBkUZFt9WtY_Eg6YtsyqXuCZWZR0.mat (method=NO_EXTRACT).
# I0508 00:27:32.874243 140300685535040 download_manager.py:291] URL https://www.robots.ox.ac.uk/~vgg/data/flowers/102/setid.mat already downloaded: reusing /home/dimitriosrou/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_setidRrhnj5H9ldPI9P6rgNJxpsg0od2Jb-Kf0-atnOXI3M0.mat.
# I0508 00:27:32.875228 140300685535040 download_manager.py:318] Skipping extraction for /home/dimitriosrou/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_setidRrhnj5H9ldPI9P6rgNJxpsg0od2Jb-Kf0-atnOXI3M0.mat (method=NO_EXTRACT).
# /home/dimitriosrou/anaconda3/envs/udacity_gpu/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.robots.ox.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   0%|                                     | 0/328 [00:00<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:01<?, ? url/s]
# Dl Size...:   0%|                             | 1/328 [00:01<09:55,  1.82s/ MiB]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:03<?, ? url/s]
# Dl Size...:   1%|▏                            | 2/328 [00:03<08:57,  1.65s/ MiB]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:   1%|▎                            | 3/328 [00:04<08:15,  1.53s/ MiB]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:   1%|▎                            | 4/328 [00:05<07:43,  1.43s/ MiB]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:06<?, ? url/s]
# Dl Size...:   2%|▍                            | 5/328 [00:06<07:21,  1.37s/ MiB]
#
# Extraction completed...: 0 file [00:06, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:   2%|▌                            | 6/328 [00:07<07:05,  1.32s/ MiB]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:   2%|▌                            | 7/328 [00:09<06:53,  1.29s/ MiB]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:10<?, ? url/s]
# Dl Size...:   2%|▋                            | 8/328 [00:10<06:46,  1.27s/ MiB]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:12<?, ? url/s]
# Dl Size...:   3%|▊                            | 9/328 [00:12<08:34,  1.61s/ MiB]
#
# Extraction completed...: 0 file [00:12, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:14<?, ? url/s]
# Dl Size...:   3%|▊                           | 10/328 [00:14<08:23,  1.58s/ MiB]
#
# Extraction completed...: 0 file [00:14, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:16<?, ? url/s]
# Dl Size...:   3%|▉                           | 11/328 [00:16<08:54,  1.69s/ MiB]
#
# Extraction completed...: 0 file [00:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:18<?, ? url/s]
# Dl Size...:   4%|█                           | 12/328 [00:18<09:43,  1.85s/ MiB]
#
# Extraction completed...: 0 file [00:18, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:20<?, ? url/s]
# Dl Size...:   4%|█                           | 13/328 [00:20<09:17,  1.77s/ MiB]
#
# Extraction completed...: 0 file [00:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:21<?, ? url/s]
# Dl Size...:   4%|█▏                          | 14/328 [00:21<08:29,  1.62s/ MiB]
#
# Extraction completed...: 0 file [00:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:22<?, ? url/s]
# Dl Size...:   5%|█▎                          | 15/328 [00:22<07:49,  1.50s/ MiB]
#
# Extraction completed...: 0 file [00:22, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:23<?, ? url/s]
# Dl Size...:   5%|█▎                          | 16/328 [00:23<07:22,  1.42s/ MiB]
#
# Extraction completed...: 0 file [00:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:25<?, ? url/s]
# Dl Size...:   5%|█▍                          | 17/328 [00:25<07:04,  1.37s/ MiB]
#
# Extraction completed...: 0 file [00:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:26<?, ? url/s]
# Dl Size...:   5%|█▌                          | 18/328 [00:26<06:57,  1.35s/ MiB]
#
# Extraction completed...: 0 file [00:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:27<?, ? url/s]
# Dl Size...:   6%|█▌                          | 19/328 [00:27<06:43,  1.31s/ MiB]
#
# Extraction completed...: 0 file [00:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:28<?, ? url/s]
# Dl Size...:   6%|█▋                          | 20/328 [00:28<06:45,  1.32s/ MiB]
#
# Extraction completed...: 0 file [00:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:30<?, ? url/s]
# Dl Size...:   6%|█▊                          | 21/328 [00:30<07:06,  1.39s/ MiB]
#
# Extraction completed...: 0 file [00:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:31<?, ? url/s]
# Dl Size...:   7%|█▉                          | 22/328 [00:31<06:52,  1.35s/ MiB]
#
# Extraction completed...: 0 file [00:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:32<?, ? url/s]
# Dl Size...:   7%|█▉                          | 23/328 [00:32<06:38,  1.31s/ MiB]
# Extraction completed...: 0 file [00:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:34<?, ? url/s]
# Dl Size...:   7%|██                          | 24/328 [00:34<06:28,  1.28s/ MiB]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:35<?, ? url/s]
# Dl Size...:   8%|██▏                         | 25/328 [00:35<06:49,  1.35s/ MiB]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:36<?, ? url/s]
# Dl Size...:   8%|██▏                         | 26/328 [00:36<06:44,  1.34s/ MiB]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:38<?, ? url/s]
# Dl Size...:   8%|██▎                         | 27/328 [00:38<06:31,  1.30s/ MiB]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:39<?, ? url/s]
# Dl Size...:   9%|██▍                         | 28/328 [00:39<06:23,  1.28s/ MiB]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:40<?, ? url/s]
# Dl Size...:   9%|██▍                         | 29/328 [00:40<06:17,  1.26s/ MiB]
#
# Extraction completed...: 0 file [00:40, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:42<?, ? url/s]
# Dl Size...:   9%|██▌                         | 30/328 [00:42<07:35,  1.53s/ MiB]
#
# Extraction completed...: 0 file [00:42, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:44<?, ? url/s]
# Dl Size...:   9%|██▋                         | 31/328 [00:44<08:09,  1.65s/ MiB]
#
# Extraction completed...: 0 file [00:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:46<?, ? url/s]
# Dl Size...:  10%|██▋                         | 32/328 [00:46<08:13,  1.67s/ MiB]
#
# Extraction completed...: 0 file [00:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:47<?, ? url/s]
# Dl Size...:  10%|██▊                         | 33/328 [00:47<07:48,  1.59s/ MiB]
#
# Extraction completed...: 0 file [00:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:49<?, ? url/s]
# Dl Size...:  10%|██▉                         | 34/328 [00:49<07:15,  1.48s/ MiB]
#
# Extraction completed...: 0 file [00:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:50<?, ? url/s]
# Dl Size...:  11%|██▉                         | 35/328 [00:50<06:50,  1.40s/ MiB]
#
# Extraction completed...: 0 file [00:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:51<?, ? url/s]
# Dl Size...:  11%|███                         | 36/328 [00:51<06:33,  1.35s/ MiB]
#
# Extraction completed...: 0 file [00:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:52<?, ? url/s]
# Dl Size...:  11%|███▏                        | 37/328 [00:52<06:20,  1.31s/ MiB]
#
# Extraction completed...: 0 file [00:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:53<?, ? url/s]
# Dl Size...:  12%|███▏                        | 38/328 [00:53<06:18,  1.30s/ MiB]
#
# Extraction completed...: 0 file [00:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:55<?, ? url/s]
# Dl Size...:  12%|███▎                        | 39/328 [00:55<06:09,  1.28s/ MiB]
#
# Extraction completed...: 0 file [00:55, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:56<?, ? url/s]
# Dl Size...:  12%|███▍                        | 40/328 [00:56<06:02,  1.26s/ MiB]
#
# Extraction completed...: 0 file [00:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:57<?, ? url/s]
# Dl Size...:  12%|███▌                        | 41/328 [00:57<05:57,  1.25s/ MiB]
#
# Extraction completed...: 0 file [00:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:58<?, ? url/s]
# Dl Size...:  13%|███▌                        | 42/328 [00:58<05:53,  1.24s/ MiB]
#
# Extraction completed...: 0 file [00:58, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:00<?, ? url/s]
# Dl Size...:  13%|███▋                        | 43/328 [01:00<05:51,  1.23s/ MiB]
#
# Extraction completed...: 0 file [01:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:01<?, ? url/s]
# Dl Size...:  13%|███▊                        | 44/328 [01:01<05:48,  1.23s/ MiB]
#
# Extraction completed...: 0 file [01:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:02<?, ? url/s]
# Dl Size...:  14%|███▊                        | 45/328 [01:02<05:46,  1.23s/ MiB]
#
# Extraction completed...: 0 file [01:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:03<?, ? url/s]
# Dl Size...:  14%|███▉                        | 46/328 [01:03<05:52,  1.25s/ MiB]
#
# Extraction completed...: 0 file [01:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:06<?, ? url/s]
# Dl Size...:  14%|████                        | 47/328 [01:06<07:47,  1.66s/ MiB]
#
# Extraction completed...: 0 file [01:06, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:08<?, ? url/s]
# Dl Size...:  15%|████                        | 48/328 [01:08<08:02,  1.72s/ MiB]
#
# Extraction completed...: 0 file [01:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:09<?, ? url/s]
# Dl Size...:  15%|████▏                       | 49/328 [01:09<07:31,  1.62s/ MiB]
#
# Extraction completed...: 0 file [01:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:12<?, ? url/s]
# Dl Size...:  15%|████▎                       | 50/328 [01:12<08:37,  1.86s/ MiB]
#
# Extraction completed...: 0 file [01:12, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:13<?, ? url/s]
# Dl Size...:  16%|████▎                       | 51/328 [01:13<08:38,  1.87s/ MiB]
#
# Extraction completed...: 0 file [01:13, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:15<?, ? url/s]
# Dl Size...:  16%|████▍                       | 52/328 [01:15<07:59,  1.74s/ MiB]
#
# Extraction completed...: 0 file [01:15, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:16<?, ? url/s]
# Dl Size...:  16%|████▌                       | 53/328 [01:16<07:16,  1.59s/ MiB]
#
# Extraction completed...: 0 file [01:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:18<?, ? url/s]
# Dl Size...:  16%|████▌                       | 54/328 [01:18<07:38,  1.67s/ MiB]
#
# Extraction completed...: 0 file [01:18, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:19<?, ? url/s]
# Dl Size...:  17%|████▋                       | 55/328 [01:19<07:18,  1.61s/ MiB]
#
# Extraction completed...: 0 file [01:19, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:21<?, ? url/s]
# Dl Size...:  17%|████▊                       | 56/328 [01:21<06:48,  1.50s/ MiB]
#
# Extraction completed...: 0 file [01:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:22<?, ? url/s]
# Dl Size...:  17%|████▊                       | 57/328 [01:22<06:23,  1.41s/ MiB]
#
# Extraction completed...: 0 file [01:22, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:23<?, ? url/s]
# Dl Size...:  18%|████▉                       | 58/328 [01:23<06:05,  1.35s/ MiB]
#
# Extraction completed...: 0 file [01:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:24<?, ? url/s]
# Dl Size...:  18%|█████                       | 59/328 [01:24<05:56,  1.33s/ MiB]
#
# Extraction completed...: 0 file [01:24, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:26<?, ? url/s]
# Dl Size...:  18%|█████                       | 60/328 [01:26<05:49,  1.30s/ MiB]
# Extraction completed...: 0 file [01:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:27<?, ? url/s]
# Dl Size...:  19%|█████▏                      | 61/328 [01:27<05:40,  1.27s/ MiB]
#
# Extraction completed...: 0 file [01:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:28<?, ? url/s]
# Dl Size...:  19%|█████▎                      | 62/328 [01:28<05:34,  1.26s/ MiB]
#
# Extraction completed...: 0 file [01:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:29<?, ? url/s]
# Dl Size...:  19%|█████▍                      | 63/328 [01:29<05:33,  1.26s/ MiB]
#
# Extraction completed...: 0 file [01:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:31<?, ? url/s]
# Dl Size...:  20%|█████▍                      | 64/328 [01:31<05:25,  1.23s/ MiB]
#
# Extraction completed...: 0 file [01:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:32<?, ? url/s]
# Dl Size...:  20%|█████▌                      | 65/328 [01:32<05:29,  1.25s/ MiB]
#
# Extraction completed...: 0 file [01:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:33<?, ? url/s]
# Dl Size...:  20%|█████▋                      | 66/328 [01:33<05:20,  1.22s/ MiB]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:34<?, ? url/s]
# Dl Size...:  20%|█████▋                      | 67/328 [01:34<05:23,  1.24s/ MiB]
#
# Extraction completed...: 0 file [01:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:40<?, ? url/s]
# Dl Size...:  21%|█████▊                      | 68/328 [01:40<10:36,  2.45s/ MiB]
#
# Extraction completed...: 0 file [01:40, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:43<?, ? url/s]
# Dl Size...:  21%|█████▉                      | 69/328 [01:43<12:13,  2.83s/ MiB]
#
# Extraction completed...: 0 file [01:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:46<?, ? url/s]
# Dl Size...:  21%|█████▉                      | 70/328 [01:46<12:24,  2.89s/ MiB]
#
# Extraction completed...: 0 file [01:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:48<?, ? url/s]
# Dl Size...:  22%|██████                      | 71/328 [01:48<11:02,  2.58s/ MiB]
#
# Extraction completed...: 0 file [01:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:50<?, ? url/s]
# Dl Size...:  22%|██████▏                     | 72/328 [01:50<10:08,  2.38s/ MiB]
#
# Extraction completed...: 0 file [01:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:52<?, ? url/s]
# Dl Size...:  22%|██████▏                     | 73/328 [01:52<09:31,  2.24s/ MiB]
#
# Extraction completed...: 0 file [01:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:56<?, ? url/s]
# Dl Size...:  23%|██████▎                     | 74/328 [01:56<11:31,  2.72s/ MiB]
#
# Extraction completed...: 0 file [01:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:58<?, ? url/s]
# Dl Size...:  23%|██████▍                     | 75/328 [01:58<10:35,  2.51s/ MiB]
#
# Extraction completed...: 0 file [01:58, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:00<?, ? url/s]
# Dl Size...:  23%|██████▍                     | 76/328 [02:00<10:09,  2.42s/ MiB]
#
# Extraction completed...: 0 file [02:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:02<?, ? url/s]
# Dl Size...:  23%|██████▌                     | 77/328 [02:02<09:12,  2.20s/ MiB]
#
# Extraction completed...: 0 file [02:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:03<?, ? url/s]
# Dl Size...:  24%|██████▋                     | 78/328 [02:03<08:16,  1.99s/ MiB]
#
# Extraction completed...: 0 file [02:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:05<?, ? url/s]
# Dl Size...:  24%|██████▋                     | 79/328 [02:05<07:58,  1.92s/ MiB]
#
# Extraction completed...: 0 file [02:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:06<?, ? url/s]
# Dl Size...:  24%|██████▊                     | 80/328 [02:06<07:19,  1.77s/ MiB]
#
# Extraction completed...: 0 file [02:06, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:08<?, ? url/s]
# Dl Size...:  25%|██████▉                     | 81/328 [02:08<06:36,  1.61s/ MiB]
#
# Extraction completed...: 0 file [02:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:09<?, ? url/s]
# Dl Size...:  25%|███████                     | 82/328 [02:09<06:35,  1.61s/ MiB]
#
# Extraction completed...: 0 file [02:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:12<?, ? url/s]
# Dl Size...:  25%|███████                     | 83/328 [02:12<07:52,  1.93s/ MiB]
#
# Extraction completed...: 0 file [02:12, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:14<?, ? url/s]
# Dl Size...:  26%|███████▏                    | 84/328 [02:14<08:35,  2.11s/ MiB]
#
# Extraction completed...: 0 file [02:14, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:16<?, ? url/s]
# Dl Size...:  26%|███████▎                    | 85/328 [02:16<07:54,  1.95s/ MiB]
#
# Extraction completed...: 0 file [02:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:17<?, ? url/s]
# Dl Size...:  26%|███████▎                    | 86/328 [02:17<07:14,  1.80s/ MiB]
#
# Extraction completed...: 0 file [02:17, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:19<?, ? url/s]
# Dl Size...:  27%|███████▍                    | 87/328 [02:19<07:19,  1.82s/ MiB]
#
# Extraction completed...: 0 file [02:19, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:21<?, ? url/s]
# Dl Size...:  27%|███████▌                    | 88/328 [02:21<07:18,  1.83s/ MiB]
#
# Extraction completed...: 0 file [02:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:23<?, ? url/s]
# Dl Size...:  27%|███████▌                    | 89/328 [02:23<07:12,  1.81s/ MiB]
#
# Extraction completed...: 0 file [02:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:25<?, ? url/s]
# Dl Size...:  27%|███████▋                    | 90/328 [02:25<07:49,  1.97s/ MiB]
#
# Extraction completed...: 0 file [02:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:27<?, ? url/s]
# Dl Size...:  28%|███████▊                    | 91/328 [02:27<07:18,  1.85s/ MiB]
#
# Extraction completed...: 0 file [02:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:28<?, ? url/s]
# Dl Size...:  28%|███████▊                    | 92/328 [02:28<06:37,  1.68s/ MiB]
#
# Extraction completed...: 0 file [02:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:30<?, ? url/s]
# Dl Size...:  28%|███████▉                    | 93/328 [02:30<06:56,  1.77s/ MiB]
#
# Extraction completed...: 0 file [02:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:32<?, ? url/s]
# Dl Size...:  29%|████████                    | 94/328 [02:32<06:32,  1.68s/ MiB]
#
# Extraction completed...: 0 file [02:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:33<?, ? url/s]
# Dl Size...:  29%|████████                    | 95/328 [02:33<05:58,  1.54s/ MiB]
#
# Extraction completed...: 0 file [02:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:35<?, ? url/s]
# Dl Size...:  29%|████████▏                   | 96/328 [02:35<06:15,  1.62s/ MiB]
#
# Extraction completed...: 0 file [02:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:36<?, ? url/s]
# Dl Size...:  30%|████████▎                   | 97/328 [02:36<06:04,  1.58s/ MiB]
# Extraction completed...: 0 file [02:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:37<?, ? url/s]
# Dl Size...:  30%|████████▎                   | 98/328 [02:37<05:39,  1.47s/ MiB]
#
# Extraction completed...: 0 file [02:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:39<?, ? url/s]
# Dl Size...:  30%|████████▍                   | 99/328 [02:39<05:31,  1.45s/ MiB]
#
# Extraction completed...: 0 file [02:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:41<?, ? url/s]
# Dl Size...:  30%|████████▏                  | 100/328 [02:41<07:00,  1.84s/ MiB]
#
# Extraction completed...: 0 file [02:41, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:45<?, ? url/s]
# Dl Size...:  31%|████████▎                  | 101/328 [02:45<09:15,  2.45s/ MiB]
#
# Extraction completed...: 0 file [02:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:47<?, ? url/s]
# Dl Size...:  31%|████████▍                  | 102/328 [02:47<08:23,  2.23s/ MiB]
#
# Extraction completed...: 0 file [02:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:48<?, ? url/s]
# Dl Size...:  31%|████████▍                  | 103/328 [02:48<07:18,  1.95s/ MiB]
#
# Extraction completed...: 0 file [02:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:50<?, ? url/s]
# Dl Size...:  32%|████████▌                  | 104/328 [02:50<07:09,  1.92s/ MiB]
#
# Extraction completed...: 0 file [02:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:52<?, ? url/s]
# Dl Size...:  32%|████████▋                  | 105/328 [02:52<06:56,  1.87s/ MiB]
#
# Extraction completed...: 0 file [02:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:54<?, ? url/s]
# Dl Size...:  32%|████████▋                  | 106/328 [02:54<06:37,  1.79s/ MiB]
#
# Extraction completed...: 0 file [02:54, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:56<?, ? url/s]
# Dl Size...:  33%|████████▊                  | 107/328 [02:56<06:53,  1.87s/ MiB]
#
# Extraction completed...: 0 file [02:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:57<?, ? url/s]
# Dl Size...:  33%|████████▉                  | 108/328 [02:57<06:46,  1.85s/ MiB]
#
# Extraction completed...: 0 file [02:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [02:59<?, ? url/s]
# Dl Size...:  33%|████████▉                  | 109/328 [02:59<06:21,  1.74s/ MiB]
#
# Extraction completed...: 0 file [02:59, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:01<?, ? url/s]
# Dl Size...:  34%|█████████                  | 110/328 [03:01<07:09,  1.97s/ MiB]
#
# Extraction completed...: 0 file [03:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:03<?, ? url/s]
# Dl Size...:  34%|█████████▏                 | 111/328 [03:03<06:45,  1.87s/ MiB]
#
# Extraction completed...: 0 file [03:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:05<?, ? url/s]
# Dl Size...:  34%|█████████▏                 | 112/328 [03:05<06:28,  1.80s/ MiB]
#
# Extraction completed...: 0 file [03:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:06<?, ? url/s]
# Dl Size...:  34%|█████████▎                 | 113/328 [03:06<05:56,  1.66s/ MiB]
#
# Extraction completed...: 0 file [03:06, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:07<?, ? url/s]
# Dl Size...:  35%|█████████▍                 | 114/328 [03:07<05:27,  1.53s/ MiB]
#
# Extraction completed...: 0 file [03:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:09<?, ? url/s]
# Dl Size...:  35%|█████████▍                 | 115/328 [03:09<06:06,  1.72s/ MiB]
#
# Extraction completed...: 0 file [03:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:13<?, ? url/s]
# Dl Size...:  35%|█████████▌                 | 116/328 [03:13<08:34,  2.43s/ MiB]
#
# Extraction completed...: 0 file [03:13, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:16<?, ? url/s]
# Dl Size...:  36%|█████████▋                 | 117/328 [03:16<08:31,  2.43s/ MiB]
#
# Extraction completed...: 0 file [03:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:18<?, ? url/s]
# Dl Size...:  36%|█████████▋                 | 118/328 [03:18<08:11,  2.34s/ MiB]
#
# Extraction completed...: 0 file [03:18, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:20<?, ? url/s]
# Dl Size...:  36%|█████████▊                 | 119/328 [03:20<08:05,  2.32s/ MiB]
#
# Extraction completed...: 0 file [03:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:22<?, ? url/s]
# Dl Size...:  37%|█████████▉                 | 120/328 [03:22<07:34,  2.18s/ MiB]
#
# Extraction completed...: 0 file [03:22, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:24<?, ? url/s]
# Dl Size...:  37%|█████████▉                 | 121/328 [03:24<06:54,  2.00s/ MiB]
#
# Extraction completed...: 0 file [03:24, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:25<?, ? url/s]
# Dl Size...:  37%|██████████                 | 122/328 [03:25<06:08,  1.79s/ MiB]
#
# Extraction completed...: 0 file [03:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:27<?, ? url/s]
# Dl Size...:  38%|██████████▏                | 123/328 [03:27<06:15,  1.83s/ MiB]
#
# Extraction completed...: 0 file [03:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:30<?, ? url/s]
# Dl Size...:  38%|██████████▏                | 124/328 [03:30<06:58,  2.05s/ MiB]
#
# Extraction completed...: 0 file [03:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:31<?, ? url/s]
# Dl Size...:  38%|██████████▎                | 125/328 [03:31<06:35,  1.95s/ MiB]
#
# Extraction completed...: 0 file [03:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:33<?, ? url/s]
# Dl Size...:  38%|██████████▎                | 126/328 [03:33<06:13,  1.85s/ MiB]
#
# Extraction completed...: 0 file [03:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:34<?, ? url/s]
# Dl Size...:  39%|██████████▍                | 127/328 [03:34<05:42,  1.70s/ MiB]
#
# Extraction completed...: 0 file [03:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:35<?, ? url/s]
# Dl Size...:  39%|██████████▌                | 128/328 [03:35<05:13,  1.57s/ MiB]
#
# Extraction completed...: 0 file [03:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:37<?, ? url/s]
# Dl Size...:  39%|██████████▌                | 129/328 [03:37<04:51,  1.46s/ MiB]
#
# Extraction completed...: 0 file [03:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:39<?, ? url/s]
# Dl Size...:  40%|██████████▋                | 130/328 [03:39<05:16,  1.60s/ MiB]
#
# Extraction completed...: 0 file [03:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:41<?, ? url/s]
# Dl Size...:  40%|██████████▊                | 131/328 [03:41<06:14,  1.90s/ MiB]
#
# Extraction completed...: 0 file [03:41, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:43<?, ? url/s]
# Dl Size...:  40%|██████████▊                | 132/328 [03:43<06:28,  1.98s/ MiB]
#
# Extraction completed...: 0 file [03:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:45<?, ? url/s]
# Dl Size...:  41%|██████████▉                | 133/328 [03:45<06:17,  1.94s/ MiB]
#
# Extraction completed...: 0 file [03:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:47<?, ? url/s]
# Dl Size...:  41%|███████████                | 134/328 [03:47<05:45,  1.78s/ MiB]
# Extraction completed...: 0 file [03:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:49<?, ? url/s]
# Dl Size...:  41%|███████████                | 135/328 [03:49<05:59,  1.86s/ MiB]
#
# Extraction completed...: 0 file [03:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:50<?, ? url/s]
# Dl Size...:  41%|███████████▏               | 136/328 [03:50<05:40,  1.77s/ MiB]
#
# Extraction completed...: 0 file [03:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:52<?, ? url/s]
# Dl Size...:  42%|███████████▎               | 137/328 [03:52<05:08,  1.62s/ MiB]
#
# Extraction completed...: 0 file [03:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:53<?, ? url/s]
# Dl Size...:  42%|███████████▎               | 138/328 [03:53<04:44,  1.50s/ MiB]
#
# Extraction completed...: 0 file [03:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:54<?, ? url/s]
# Dl Size...:  42%|███████████▍               | 139/328 [03:54<04:58,  1.58s/ MiB]
#
# Extraction completed...: 0 file [03:54, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:56<?, ? url/s]
# Dl Size...:  43%|███████████▌               | 140/328 [03:56<04:50,  1.54s/ MiB]
#
# Extraction completed...: 0 file [03:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:57<?, ? url/s]
# Dl Size...:  43%|███████████▌               | 141/328 [03:57<04:47,  1.54s/ MiB]
#
# Extraction completed...: 0 file [03:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [03:59<?, ? url/s]
# Dl Size...:  43%|███████████▋               | 142/328 [03:59<04:30,  1.46s/ MiB]
#
# Extraction completed...: 0 file [03:59, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:00<?, ? url/s]
# Dl Size...:  44%|███████████▊               | 143/328 [04:00<04:32,  1.47s/ MiB]
#
# Extraction completed...: 0 file [04:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:02<?, ? url/s]
# Dl Size...:  44%|███████████▊               | 144/328 [04:02<04:18,  1.41s/ MiB]
#
# Extraction completed...: 0 file [04:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:03<?, ? url/s]
# Dl Size...:  44%|███████████▉               | 145/328 [04:03<04:08,  1.36s/ MiB]
#
# Extraction completed...: 0 file [04:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:04<?, ? url/s]
# Dl Size...:  45%|████████████               | 146/328 [04:04<04:07,  1.36s/ MiB]
#
# Extraction completed...: 0 file [04:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:05<?, ? url/s]
# Dl Size...:  45%|████████████               | 147/328 [04:05<04:01,  1.34s/ MiB]
#
# Extraction completed...: 0 file [04:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:07<?, ? url/s]
# Dl Size...:  45%|████████████▏              | 148/328 [04:07<03:53,  1.30s/ MiB]
#
# Extraction completed...: 0 file [04:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:08<?, ? url/s]
# Dl Size...:  45%|████████████▎              | 149/328 [04:08<03:57,  1.32s/ MiB]
#
# Extraction completed...: 0 file [04:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:10<?, ? url/s]
# Dl Size...:  46%|████████████▎              | 150/328 [04:10<04:44,  1.60s/ MiB]
#
# Extraction completed...: 0 file [04:10, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:13<?, ? url/s]
# Dl Size...:  46%|████████████▍              | 151/328 [04:13<05:29,  1.86s/ MiB]
#
# Extraction completed...: 0 file [04:13, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:14<?, ? url/s]
# Dl Size...:  46%|████████████▌              | 152/328 [04:14<05:19,  1.81s/ MiB]
#
# Extraction completed...: 0 file [04:14, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:17<?, ? url/s]
# Dl Size...:  47%|████████████▌              | 153/328 [04:17<05:37,  1.93s/ MiB]
#
# Extraction completed...: 0 file [04:17, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:20<?, ? url/s]
# Dl Size...:  47%|████████████▋              | 154/328 [04:20<07:14,  2.50s/ MiB]
#
# Extraction completed...: 0 file [04:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:23<?, ? url/s]
# Dl Size...:  47%|████████████▊              | 155/328 [04:23<07:26,  2.58s/ MiB]
#
# Extraction completed...: 0 file [04:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:27<?, ? url/s]
# Dl Size...:  48%|████████████▊              | 156/328 [04:27<08:33,  2.99s/ MiB]
#
# Extraction completed...: 0 file [04:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:33<?, ? url/s]
# Dl Size...:  48%|████████████▉              | 157/328 [04:33<10:52,  3.81s/ MiB]
#
# Extraction completed...: 0 file [04:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:44<?, ? url/s]
# Dl Size...:  48%|█████████████              | 158/328 [04:44<16:45,  5.91s/ MiB]
#
# Extraction completed...: 0 file [04:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:46<?, ? url/s]
# Dl Size...:  48%|█████████████              | 159/328 [04:46<13:26,  4.77s/ MiB]
#
# Extraction completed...: 0 file [04:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:48<?, ? url/s]
# Dl Size...:  49%|█████████████▏             | 160/328 [04:48<11:05,  3.96s/ MiB]
#
# Extraction completed...: 0 file [04:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:49<?, ? url/s]
# Dl Size...:  49%|█████████████▎             | 161/328 [04:49<08:47,  3.16s/ MiB]
#
# Extraction completed...: 0 file [04:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:50<?, ? url/s]
# Dl Size...:  49%|█████████████▎             | 162/328 [04:50<07:07,  2.58s/ MiB]
#
# Extraction completed...: 0 file [04:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:52<?, ? url/s]
# Dl Size...:  50%|█████████████▍             | 163/328 [04:52<06:02,  2.19s/ MiB]
#
# Extraction completed...: 0 file [04:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:53<?, ? url/s]
# Dl Size...:  50%|█████████████▌             | 164/328 [04:53<05:15,  1.92s/ MiB]
#
# Extraction completed...: 0 file [04:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:54<?, ? url/s]
# Dl Size...:  50%|█████████████▌             | 165/328 [04:54<04:43,  1.74s/ MiB]
#
# Extraction completed...: 0 file [04:54, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:56<?, ? url/s]
# Dl Size...:  51%|█████████████▋             | 166/328 [04:56<04:16,  1.58s/ MiB]
#
# Extraction completed...: 0 file [04:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:57<?, ? url/s]
# Dl Size...:  51%|█████████████▋             | 167/328 [04:57<03:57,  1.47s/ MiB]
#
# Extraction completed...: 0 file [04:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:58<?, ? url/s]
# Dl Size...:  51%|█████████████▊             | 168/328 [04:58<03:43,  1.40s/ MiB]
#
# Extraction completed...: 0 file [04:58, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [04:59<?, ? url/s]
# Dl Size...:  52%|█████████████▉             | 169/328 [04:59<03:33,  1.34s/ MiB]
#
# Extraction completed...: 0 file [04:59, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:00<?, ? url/s]
# Dl Size...:  52%|█████████████▉             | 170/328 [05:00<03:27,  1.31s/ MiB]
#
# Extraction completed...: 0 file [05:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:02<?, ? url/s]
# Dl Size...:  52%|██████████████             | 171/328 [05:02<03:31,  1.34s/ MiB]
# Extraction completed...: 0 file [05:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:03<?, ? url/s]
# Dl Size...:  52%|██████████████▏            | 172/328 [05:03<03:28,  1.34s/ MiB]
#
# Extraction completed...: 0 file [05:03, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:05<?, ? url/s]
# Dl Size...:  53%|██████████████▏            | 173/328 [05:05<03:46,  1.46s/ MiB]
#
# Extraction completed...: 0 file [05:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:07<?, ? url/s]
# Dl Size...:  53%|██████████████▎            | 174/328 [05:07<04:34,  1.78s/ MiB]
#
# Extraction completed...: 0 file [05:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:09<?, ? url/s]
# Dl Size...:  53%|██████████████▍            | 175/328 [05:09<04:28,  1.76s/ MiB]
#
# Extraction completed...: 0 file [05:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:12<?, ? url/s]
# Dl Size...:  54%|██████████████▍            | 176/328 [05:12<04:56,  1.95s/ MiB]
#
# Extraction completed...: 0 file [05:12, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:13<?, ? url/s]
# Dl Size...:  54%|██████████████▌            | 177/328 [05:13<04:54,  1.95s/ MiB]
#
# Extraction completed...: 0 file [05:13, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:15<?, ? url/s]
# Dl Size...:  54%|██████████████▋            | 178/328 [05:15<04:27,  1.78s/ MiB]
#
# Extraction completed...: 0 file [05:15, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:16<?, ? url/s]
# Dl Size...:  55%|██████████████▋            | 179/328 [05:16<04:00,  1.61s/ MiB]
#
# Extraction completed...: 0 file [05:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:17<?, ? url/s]
# Dl Size...:  55%|██████████████▊            | 180/328 [05:17<03:40,  1.49s/ MiB]
#
# Extraction completed...: 0 file [05:17, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:19<?, ? url/s]
# Dl Size...:  55%|██████████████▉            | 181/328 [05:19<03:27,  1.41s/ MiB]
#
# Extraction completed...: 0 file [05:19, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:20<?, ? url/s]
# Dl Size...:  55%|██████████████▉            | 182/328 [05:20<03:18,  1.36s/ MiB]
#
# Extraction completed...: 0 file [05:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:21<?, ? url/s]
# Dl Size...:  56%|███████████████            | 183/328 [05:21<03:10,  1.32s/ MiB]
#
# Extraction completed...: 0 file [05:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:22<?, ? url/s]
# Dl Size...:  56%|███████████████▏           | 184/328 [05:22<03:04,  1.28s/ MiB]
#
# Extraction completed...: 0 file [05:22, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:23<?, ? url/s]
# Dl Size...:  56%|███████████████▏           | 185/328 [05:23<03:00,  1.27s/ MiB]
#
# Extraction completed...: 0 file [05:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:25<?, ? url/s]
# Dl Size...:  57%|███████████████▎           | 186/328 [05:25<03:03,  1.29s/ MiB]
#
# Extraction completed...: 0 file [05:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:26<?, ? url/s]
# Dl Size...:  57%|███████████████▍           | 187/328 [05:26<03:17,  1.40s/ MiB]
#
# Extraction completed...: 0 file [05:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:28<?, ? url/s]
# Dl Size...:  57%|███████████████▍           | 188/328 [05:28<03:11,  1.37s/ MiB]
#
# Extraction completed...: 0 file [05:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:29<?, ? url/s]
# Dl Size...:  58%|███████████████▌           | 189/328 [05:29<03:04,  1.32s/ MiB]
#
# Extraction completed...: 0 file [05:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:30<?, ? url/s]
# Dl Size...:  58%|███████████████▋           | 190/328 [05:30<02:58,  1.29s/ MiB]
#
# Extraction completed...: 0 file [05:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:31<?, ? url/s]
# Dl Size...:  58%|███████████████▋           | 191/328 [05:31<02:54,  1.27s/ MiB]
#
# Extraction completed...: 0 file [05:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:33<?, ? url/s]
# Dl Size...:  59%|███████████████▊           | 192/328 [05:33<02:50,  1.25s/ MiB]
#
# Extraction completed...: 0 file [05:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:34<?, ? url/s]
# Dl Size...:  59%|███████████████▉           | 193/328 [05:34<02:48,  1.25s/ MiB]
#
# Extraction completed...: 0 file [05:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:35<?, ? url/s]
# Dl Size...:  59%|███████████████▉           | 194/328 [05:35<02:45,  1.24s/ MiB]
#
# Extraction completed...: 0 file [05:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:36<?, ? url/s]
# Dl Size...:  59%|████████████████           | 195/328 [05:36<02:43,  1.23s/ MiB]
#
# Extraction completed...: 0 file [05:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:37<?, ? url/s]
# Dl Size...:  60%|████████████████▏          | 196/328 [05:37<02:41,  1.23s/ MiB]
#
# Extraction completed...: 0 file [05:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:39<?, ? url/s]
# Dl Size...:  60%|████████████████▏          | 197/328 [05:39<02:40,  1.22s/ MiB]
#
# Extraction completed...: 0 file [05:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:40<?, ? url/s]
# Dl Size...:  60%|████████████████▎          | 198/328 [05:40<02:38,  1.22s/ MiB]
#
# Extraction completed...: 0 file [05:40, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:43<?, ? url/s]
# Dl Size...:  61%|████████████████▍          | 199/328 [05:43<03:59,  1.86s/ MiB]
#
# Extraction completed...: 0 file [05:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:45<?, ? url/s]
# Dl Size...:  61%|████████████████▍          | 200/328 [05:45<03:57,  1.86s/ MiB]
#
# Extraction completed...: 0 file [05:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:47<?, ? url/s]
# Dl Size...:  61%|████████████████▌          | 201/328 [05:47<03:41,  1.75s/ MiB]
#
# Extraction completed...: 0 file [05:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:48<?, ? url/s]
# Dl Size...:  62%|████████████████▋          | 202/328 [05:48<03:43,  1.77s/ MiB]
#
# Extraction completed...: 0 file [05:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:50<?, ? url/s]
# Dl Size...:  62%|████████████████▋          | 203/328 [05:50<03:27,  1.66s/ MiB]
#
# Extraction completed...: 0 file [05:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:52<?, ? url/s]
# Dl Size...:  62%|████████████████▊          | 204/328 [05:52<03:34,  1.73s/ MiB]
#
# Extraction completed...: 0 file [05:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:55<?, ? url/s]
# Dl Size...:  62%|████████████████▉          | 205/328 [05:55<04:36,  2.25s/ MiB]
#
# Extraction completed...: 0 file [05:55, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:57<?, ? url/s]
# Dl Size...:  63%|████████████████▉          | 206/328 [05:57<04:21,  2.15s/ MiB]
#
# Extraction completed...: 0 file [05:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [05:58<?, ? url/s]
# Dl Size...:  63%|█████████████████          | 207/328 [05:58<03:52,  1.92s/ MiB]
#
# Extraction completed...: 0 file [05:58, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [06:00<?, ? url/s]
# Dl Size...:  63%|█████████████████          | 208/328 [06:00<03:25,  1.71s/ MiB]
# Extraction completed...: 0 file [06:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [06:01<?, ? url/s]
# Dl Size...:  64%|█████████████████▏         | 209/328 [06:01<03:06,  1.57s/ MiB]
#
# Extraction completed...: 0 file [06:01, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [06:02<?, ? url/s]
# Dl Size...:  64%|█████████████████▎         | 210/328 [06:02<02:52,  1.46s/ MiB]
#
# Extraction completed...: 0 file [06:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [06:03<?, ? url/s]
# ...
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 1020
#         }
#         mean: 50.5
#         std_dev: 29.443448620476957
#         num_zeros: 10
#         median: 51.0
#         max: 101.0
#         histograms {
#           buckets {
#             high_value: 10.1
#             sample_count: 109.242
#           }
#           buckets {
#             low_value: 10.1
#             high_value: 20.2
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 20.2
#             high_value: 30.299999999999997
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 30.299999999999997
#             high_value: 40.4
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 40.4
#             high_value: 50.5
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 50.5
#             high_value: 60.599999999999994
#             sample_count: 101.08200000000001
#           }
#           buckets {
#             low_value: 60.599999999999994
#             high_value: 70.7
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 70.7
#             high_value: 80.8
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 80.8
#             high_value: 90.89999999999999
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 90.89999999999999
#             high_value: 101.0
#             sample_count: 109.242
#           }
#         }
#         histograms {
#           buckets {
#             high_value: 10.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 10.0
#             high_value: 20.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 20.0
#             high_value: 30.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 30.0
#             high_value: 40.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 40.0
#             high_value: 51.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 51.0
#             high_value: 61.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 61.0
#             high_value: 71.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 71.0
#             high_value: 81.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 81.0
#             high_value: 91.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 91.0
#             high_value: 101.0
#             sample_count: 102.0
#           }
#           type: QUANTILES
#         }
#       }
#       path {
#         step: "label"
#       }
#     }
#   }
#   shard_lengths: 1020
#   num_bytes: 43474584
# }
# splits {
#   name: "validation"
#   statistics {
#     num_examples: 1020
#     features {
#       type: STRING
#       string_stats {
#         common_stats {
#           num_non_missing: 1020
#           min_num_values: 1
#           max_num_values: 1
#           avg_num_values: 1.0
#           num_values_histogram {
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 1020
#         }
#         unique: 1020
#         top_values {
#           value: "image_08187.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08185.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08182.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08179.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08176.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08174.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08173.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08157.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08138.jpg"
#           frequency: 1.0
#         }
#         top_values {
#           value: "image_08133.jpg"
#           frequency: 1.0
#         }
#         avg_length: 15.0
#         rank_histogram {
#           buckets {
#             label: "image_08187.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 1
#             high_rank: 1
#             label: "image_08185.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 2
#             high_rank: 2
#             label: "image_08182.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 3
#             high_rank: 3
#             label: "image_08179.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 4
#             high_rank: 4
#             label: "image_08176.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 5
#             high_rank: 5
#             label: "image_08174.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 6
#             high_rank: 6
#             label: "image_08173.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 7
#             high_rank: 7
#             label: "image_08157.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 8
#             high_rank: 8
#             label: "image_08138.jpg"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 9
#             high_rank: 9
#             label: "image_08133.jpg"
#             sample_count: 1.0
#           }
#         }
#       }
#       path {
#         step: "file_name"
#       }
#     }
#     features {
#       type: STRING
#       string_stats {
#         common_stats {
#           num_non_missing: 1020
#           min_num_values: 1
#           max_num_values: 1
#           avg_num_values: 1.0
#           num_values_histogram {
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 1020
#         }
#         unique: 1020
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         avg_length: 42256.625
#         rank_histogram {
#           buckets {
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 1
#             high_rank: 1
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 2
#             high_rank: 2
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 3
#             high_rank: 3
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 4
#             high_rank: 4
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 5
#             high_rank: 5
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 6
#             high_rank: 6
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 7
#             high_rank: 7
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 8
#             high_rank: 8
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 9
#             high_rank: 9
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#         }
#       }
#       path {
#         step: "image"
#       }
#     }
#     features {
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#           min_num_values: 1
#           max_num_values: 1
#           avg_num_values: 1.0
#           num_values_histogram {
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 102.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 1020
#         }
#         mean: 50.5
#         std_dev: 29.443448620476957
#         num_zeros: 10
#         median: 51.0
#         max: 101.0
#         histograms {
#           buckets {
#             high_value: 10.1
#             sample_count: 109.242
#           }
#           buckets {
#             low_value: 10.1
#             high_value: 20.2
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 20.2
#             high_value: 30.299999999999997
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 30.299999999999997
#             high_value: 40.4
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 40.4
#             high_value: 50.5
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 50.5
#             high_value: 60.599999999999994
#             sample_count: 101.08200000000001
#           }
#           buckets {
#             low_value: 60.599999999999994
#             high_value: 70.7
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 70.7
#             high_value: 80.8
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 80.8
#             high_value: 90.89999999999999
#             sample_count: 100.06200000000001
#           }
#           buckets {
#             low_value: 90.89999999999999
#             high_value: 101.0
#             sample_count: 109.242
#           }
#         }
#         histograms {
#           buckets {
#             high_value: 10.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 10.0
#             high_value: 20.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 20.0
#             high_value: 30.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 30.0
#             high_value: 40.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 40.0
#             high_value: 51.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 51.0
#             high_value: 61.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 61.0
#             high_value: 71.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 71.0
#             high_value: 81.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 81.0
#             high_value: 91.0
#             sample_count: 102.0
#           }
#           buckets {
#             low_value: 91.0
#             high_value: 101.0
#             sample_count: 102.0
#           }
#           type: QUANTILES
#         }
#       }
#       path {
#         step: "label"
#       }
#     }
#   }
#   shard_lengths: 1020
#   num_bytes: 43180278
# }
# supervised_keys {
#   input: "image"
#   output: "label"
# }
# version: "2.1.1"
# download_size: 344878000

# %%
# TODO: Load the dataset with TensorFlow Datasets.
ds, ds_info = tfds.load('oxford_flowers102', with_info=True, as_supervised=True)

# TODO: Create a training set, a validation set and a test set.
training_set, validation_set, test_set = ds['train'], ds['validation'], ds['test']

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.

num_train = ds_info.splits['train'].num_examples
num_val = ds_info.splits['validation'].num_examples
num_test = ds_info.splits['test'].num_examples

print('Number of examples in training set:', num_train,
      '\nNumber of examples in validation set:', num_val,
      '\nNumber of examples in test set:', num_test)

# TODO: Get the number of classes in the dataset from the dataset info.

num_classes = ds_info.features['label'].num_classes
print('Number of classes in the dataset:', num_classes)
# Out:
# Number of examples in training set: 1020
# Number of examples in validation set: 1020
# Number of examples in test set: 6149
# Number of classes in the dataset: 102

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.

i = 1
for image, label in training_set.take(3):
    print('Image no. {} with shape {} and label {}'.format(i, image.shape, label))
    i += 1
# Out:
# Image no. 1 with shape (500, 667, 3) and label 72
# Image no. 2 with shape (500, 666, 3) and label 84
# Image no. 3 with shape (670, 500, 3) and label 70

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding image label. 

for image, label in training_set.take(1):
    image = image
    label = label
plt.imshow(image)
plt.title('Label {}'.format(label))
plt.colorbar()
plt.show()

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
with open('label_map.json', 'r') as f:
    class_names = json.load(f)

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 

class_name = class_names.get(str(label.numpy()))
plt.imshow(image)
plt.title('Label {}'.format(class_name))
plt.colorbar()
plt.show()

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.

def normalize_image(image, label):
    image = tf.cast(image, tf.float32)
    image /= 255.0
    return image, label

batch_size = 64

training_batches = training_set.cache().shuffle(num_train // 4).batch(batch_size).map(normalize_image).prefetch(1)

validation_batches = validation_set.cache().batch(batch_size).map(normalize_image).prefetch(1)

test_batches = test_set.cache().batch(batch_size).map(normalize_image).prefetch(1)

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network.

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = './test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes
